# %%
import torchvision.transforms.v2 as transforms
from data_loading import RevisedDataset
import torch
from datamodule import PokemonDataModule
from train_utils import gen_transforms
# Out:
# /home/felix/miniconda3/envs/torch/lib/python3.11/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# ...

# %%
transform_pipeline = gen_transforms("mild")

module = PokemonDataModule(val_and_pred_transforms=transform_pipeline)
val_dataset = module.get_val_dataset(True)
val_dataset.viz_transorms(crop=True)
val_dataset.viz_transorms(crop=True)
# Out:
# Could not extract dataconfig mean and std, falling back on standard
# /home/felix/Documents/deep_pokis/datamodule.py:29: DtypeWarning: Columns (1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv("data/info.csv", index_col=0)
# ...

# %%
transform_pipeline = gen_transforms("medium")

module = PokemonDataModule(val_and_pred_transforms=transform_pipeline)
val_dataset = module.get_val_dataset(True)
val_dataset.viz_transorms(crop=True)
val_dataset.viz_transorms(crop=True)
# Out:
# Could not extract dataconfig mean and std, falling back on standard
# /home/felix/Documents/deep_pokis/datamodule.py:29: DtypeWarning: Columns (1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv("data/info.csv", index_col=0)
# ...

# %%
transform_pipeline = gen_transforms("medium_strong_crop", None)
module = PokemonDataModule(val_and_pred_transforms=transform_pipeline)
val_dataset = module.get_val_dataset(True)
val_dataset.viz_transorms(crop=True)
val_dataset.viz_transorms(crop=True)
# Out:
# Could not extract dataconfig mean and std, falling back on standard
# /home/felix/Documents/deep_pokis/datamodule.py:29: DtypeWarning: Columns (1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv("data/info.csv", index_col=0)
# ...

# %%
transform_pipeline = gen_transforms("strong")
module = PokemonDataModule(val_and_pred_transforms=transform_pipeline)
val_dataset = module.get_val_dataset(True)
val_dataset.viz_transorms(crop=True)
val_dataset.viz_transorms(crop=True)
# Out:
# Could not extract dataconfig mean and std, falling back on standard
# /home/felix/Documents/deep_pokis/datamodule.py:29: DtypeWarning: Columns (1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv("data/info.csv", index_col=0)
# ...

# %%
transform_pipeline = gen_transforms("extra_strong")
module = PokemonDataModule(val_and_pred_transforms=transform_pipeline)
val_dataset = module.get_val_dataset(True)
val_dataset.viz_transorms(crop=True)
val_dataset.viz_transorms(crop=True)
# Out:
# Could not extract dataconfig mean and std, falling back on standard
# /home/felix/Documents/deep_pokis/datamodule.py:29: DtypeWarning: Columns (1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv("data/info.csv", index_col=0)
# ...
