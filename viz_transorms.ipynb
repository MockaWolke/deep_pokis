# %%
import torchvision.transforms.v2 as transforms
from data_loading import PokemonDataset
import torch
from train_utils import gen_transforms

# %%
transform_pipeline = gen_transforms("mild")
val_dataset = PokemonDataset("val", "crop", imgsz=224, transforms=transform_pipeline)
val_dataset.viz_transorms(crop=False)
val_dataset.viz_transorms(crop=False)
val_dataset.viz_transorms(crop=True)
val_dataset.viz_transorms(crop=True)
# Out:
# /home/felix/miniconda3/envs/torch/lib/python3.11/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
transform_pipeline = gen_transforms("medium")
val_dataset = PokemonDataset("val", "crop", imgsz=224, transforms=transform_pipeline)
val_dataset.viz_transorms(crop=False)
val_dataset.viz_transorms(crop=False)
val_dataset.viz_transorms(crop=True)
val_dataset.viz_transorms(crop=True)
# Out:
# /home/felix/miniconda3/envs/torch/lib/python3.11/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
transform_pipeline = gen_transforms("strong")
val_dataset = PokemonDataset("val", "crop", imgsz=224, transforms=transform_pipeline)
val_dataset.viz_transorms(crop=False)
val_dataset.viz_transorms(crop=False)
val_dataset.viz_transorms(crop=True)
val_dataset.viz_transorms(crop=True)
# Out:
# /home/felix/miniconda3/envs/torch/lib/python3.11/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
